# %%
lst = []
for i in range(109165,576723+1):
    if not False in [i<=j for i,j in zip(str(i),str(i)[1:])] and True in [i==j for i,j in zip(str(i),str(i)[1:])]:
        lst.append(i)

# %%
lst = []
for i in range(109165,576723+1):
    if not False in [i<=j for i,j in zip(str(i),str(i)[1:])] and True in [i==j for i,j in zip(str(i),str(i)[1:])]:
        lst.append(i)

# %%
len(lst)
# Out:
# 2814

# %%
for num in lst:

# %%
set(str(lst[3]))[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-2d150b86b2ee> in <module>
# ----> 1 set(str(lst[3]))[0]
#
# TypeError: 'set' object is not subscriptable

# %%
[2 in [str(num).count(char) for char in list(set(str(num)))] for num in lst]
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
# ...

# %%
import numpy as np
np.sum([2 in [str(num).count(char) for char in list(set(str(num)))] for num in lst])
# Out:
# 1991
